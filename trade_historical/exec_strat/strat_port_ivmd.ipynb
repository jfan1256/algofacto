# %%
import os
import yfinance as yf
import quantstats as qs
import scipy.cluster.hierarchy as sch
import cvxopt as opt
import matplotlib.pyplot as plt
import shutil
import base64
import cvxpy as cp

from scipy.stats import spearmanr
from io import BytesIO
from datetime import timedelta
from IPython.display import Image
from tqdm import tqdm
from sklearn.cluster import AgglomerativeClustering
from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet
from sklearn.metrics import adjusted_mutual_info_score
from sklearn import cluster, covariance, manifold
from cvxopt import blas, solvers
from IPython.display import display
from scipy.optimize import minimize
from matplotlib.backends.backend_svg import FigureCanvasSVG

from class_model.model_prep import ModelPrep
from core.system import *
from core.operation import *

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Params

# %%
# Params
live = True
start = '2005-01-01'
current_date = date.today().strftime('%Y-%m-%d')
window = 60
threshold = 2_000_000_000
stock = read_stock(get_large(live) / 'permno_live.csv')

# %%
def month(data):
    data_reset = data.reset_index()
    data_reset = data_reset.set_index('date')
    data_monthly = data_reset.groupby('permno').resample('M').last()
    data_monthly = data_monthly.reset_index(0, drop=True)
    data_monthly = data_monthly.reset_index()
    data_monthly = data_monthly.set_index(['permno', 'date'])
    return data_monthly

# %%
# Read in Data
price = pd.read_parquet(get_parquet(live) / 'data_price.parquet.brotli')
fund_q = pd.read_parquet(get_parquet(live) / 'data_fund_raw_q.parquet.brotli')
rf = pd.read_parquet(get_parquet(live) / 'data_rf.parquet.brotli')

# Resample to daily
date_index = price.drop(price.columns, axis=1)
fund_q = fund_q.groupby('permno').shift(3)
fund_q = date_index.merge(fund_q, left_index=True, right_index=True, how='left').groupby('permno').ffill()

# %% [markdown]
# # Factors

# %% [markdown]
# ### Value

# %%
# Create Book-to-Earnings Ratio
fund_q['btm'] = fund_q['ceqq']/(fund_q['cshoq']*fund_q['prccq'])
btm = fund_q[['btm']]

# %% [markdown]
# ### Momentum

# %%
def create_multi_index(factor_data, stock):
    factor_values = pd.concat([factor_data] * len(stock), ignore_index=True).values
    multi_index = pd.MultiIndex.from_product([stock, factor_data.index])
    multi_index_factor = pd.DataFrame(factor_values, columns=factor_data.columns, index=multi_index)
    multi_index_factor.index = multi_index_factor.index.set_names(['permno', 'date'])
    return multi_index_factor

# %%
def calculate_rolling_momentum(stock_data):
    # Calculate excess return
    stock_data['excess_return'] = stock_data['RET_01'] - stock_data['RF']

    # Calculate the 12-month rolling cumulative excess return, excluding the most recent month
    shifted_excess_return = stock_data['excess_return'].shift(1)
    rolling_momentum = shifted_excess_return.rolling(window=21).sum()

    return rolling_momentum

# %%
# Create momentum weights
rf_df = create_multi_index(rf, stock)
mom = price.merge(rf_df, left_index=True, right_index=True, how='left').ffill()
mom = create_return(mom, [1])

# %%
# Calculate rolling momentum for each stock
mom['mom'] = mom.groupby(level='permno').apply(calculate_rolling_momentum).reset_index(level=0, drop=True)

# %% [markdown]
# ### Defensive

# %%
# Create defensive beta weights
# Read in SPY data from FMP
T = [1]
spy = get_data_fmp(ticker_list=['SPY'], start=start, current_date=current_date)
spy = spy[['Open', 'High', 'Low', 'Volume', 'Adj Close']]
spy = spy.rename(columns={'Adj Close': 'Close'})

# Create returns and unstack dataframe to only have 'date' index and 'ETF ticker' columns
spy = create_return(spy, T)
spy = spy.drop(['Close', 'High', 'Low', 'Open', 'Volume'], axis=1)
spy = spy.unstack('ticker').swaplevel(axis=1)
spy.columns = ['_'.join(col).strip() for col in spy.columns.values]
spy = spy.fillna(0)

# Read in price data and set up params for Rolling LR
T = [1]
ret = f'RET_01'
spy_data = pd.read_parquet(get_parquet(live) / 'data_price.parquet.brotli')
factor_col_spy = spy.columns

spy_data = create_return(spy_data, T)
spy_data = spy_data.fillna(0)

# Execute Rolling LR
beta_spy = rolling_ols_parallel(data=spy_data, ret=ret, factor_data=spy, factor_cols=factor_col_spy.tolist(), window=window, name=f'spy_01')
# Out:
# Fetching data: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.01s/ticker]

# %%
defense = beta_spy[[f'SPY_RET_01_spy_01_{window}']]
defense.columns = ['beta']

# %% [markdown]
# # Setting Up Data

# %%
factor = pd.merge(mom, btm, left_index=True, right_index=True, how='left').merge(defense, left_index=True, right_index=True, how='left')

# %%
# Add market_cap
market = pd.read_parquet(get_parquet(live) / 'data_misc.parquet.brotli', columns=['market_cap'])
factor = factor.merge(market, left_index=True, right_index=True, how='left')

# %% [markdown]
# # Factor Portfolios

# %%
# Function to select top and bottom stocks
def select_long_short_stocks(group):
    top_stocks = group.nlargest(25, 'adj_weight')
    bottom_stocks = group.nsmallest(25, 'adj_weight')
    top_stocks['final_weight'] = top_stocks['adj_weight'] * 1
    bottom_stocks['final_weight'] = bottom_stocks['adj_weight'] * -1

    # top_stocks['final_weight'] = top_stocks['adj_weight'] / top_stocks['adj_weight'].abs().sum()
    # bottom_stocks['final_weight'] = bottom_stocks['adj_weight'] / bottom_stocks['adj_weight'].abs().sum()
    # top_stocks['final_weight'] *= 0.5
    # bottom_stocks['final_weight'] *= -0.5
    return pd.concat([top_stocks, bottom_stocks])

# Create Factor-Based Portfolio
def create_factor_port(data, factors, threshold):
    df = data.copy(deep=True)
    # Filtering by Market Capitalization
    df = df[df['market_cap'] >= threshold]
    # Create ranks for each factor
    print("-"*60)
    print("Creating Factor Ranks...")
    for factor_name in factors:
        print(f'Factor: {factor_name}')
        df[f'{factor_name}_Rank'] = df.groupby('date')[factor_name].rank(ascending=False)
    # Calculating average rank
    df['avg_rank'] = df[[f'{f}_Rank' for f in factors]].mean(axis=1)
    # Calculating rank weights
    df['rank_weight'] = (1 / len(factors)) * df['avg_rank']
    # Calculating inverse volatility
    df['vol'] = df.groupby('permno')['RET_01'].transform(lambda x: x.rolling(21).std())
    df['inv_vol_weight'] = 1 / df['vol']
    # Find adjusted weight that accounts for rank and inverse volatility
    df['adj_weight'] = df['rank_weight'] * df['inv_vol_weight']
    # Selecting Top and Bottom Stocks
    print("-"*60)
    print("Creating Long/Short portfolio...")
    long_short_stocks = df.groupby('date').apply(select_long_short_stocks).reset_index(level=0, drop=True)
    # Normalizing Weights
    long_short_stocks['final_weight'] /= long_short_stocks.groupby('date')['final_weight'].transform(lambda x: x.abs().sum())
    long_short_stocks['RET_01'] = long_short_stocks.groupby('permno')['RET_01'].shift(-1)
    long_short_stocks['total_ret'] = long_short_stocks['RET_01'] * long_short_stocks['final_weight']
    total_ret = long_short_stocks.groupby('date').total_ret.sum()
    qs.reports.full(total_ret, 'SPY')
    return total_ret, long_short_stocks

# %%
factors = ['mom', 'btm', 'beta']

total_ret, long_short_stocks = create_factor_port(factor, factors, threshold)
# Out:
# ------------------------------------------------------------
# Creating Factor Ranks...
# Factor: mom
# Factor: btm
# Factor: beta
# ------------------------------------------------------------
# Creating Long/Short portfolio...
# [*********************100%%**********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2005-03-01   2005-03-01
# End Period                 2024-01-19   2024-01-19
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          299.93%      209.19%
# CAGR﹪                     5.19%        4.21%
#
# Sharpe                     0.48         0.83
# Prob. Sharpe Ratio         98.04%       99.98%
# Smart Sharpe               0.46         0.8
# Sortino                    0.67         1.16
# Smart Sortino              0.65         1.12
# Sortino/√2                 0.47         0.82
# Smart Sortino/√2           0.46         0.79
# Omega                      1.17         1.17
#
# Max Drawdown               -56.47%      -32.23%
# Longest DD Days            1982         1405
# Volatility (ann.)          19.4%        7.6%
# R^2                        0.01         0.01
# Information Ratio          -0.01        -0.01
# Calmar                     0.09         0.13
# Skew                       -0.07        -0.47
# Kurtosis                   14.6         11.66
#
# Expected Daily %           0.03%        0.02%
# Expected Monthly %         0.61%        0.5%
# Expected Yearly %          7.18%        5.81%
# Kelly Criterion            0.77%        0.47%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -1.97%       -0.76%
# Expected Shortfall (cVaR)  -1.97%       -0.76%
#
# Max Consecutive Wins       14           14
# Max Consecutive Losses     8            9
# Gain/Pain Ratio            0.1          0.17
# Gain/Pain (1M)             0.58         0.83
#
# Payoff Ratio               0.85         0.84
# Profit Factor              1.1          1.17
# Common Sense Ratio         1.01         1.18
# CPC Index                  0.51         0.53
# Tail Ratio                 0.92         1.01
# Outlier Win Ratio          2.95         6.87
# Outlier Loss Ratio         2.99         7.42
#
# MTD                        1.5%         1.28%
# 3M                         12.14%       4.73%
# 6M                         6.22%        3.39%
# YTD                        1.5%         1.28%
# 1Y                         23.23%       9.2%
# 3Y (ann.)                  5.12%        4.28%
# 5Y (ann.)                  8.08%        5.33%
# 10Y (ann.)                 6.9%         5.35%
# All-time (ann.)            5.19%        4.21%
#
# Best Day                   14.52%       4.64%
# Worst Day                  -10.94%      -4.75%
# Best Month                 12.7%        6.54%
# Worst Month                -16.52%      -10.17%
# Best Year                  29.69%       17.71%
# Worst Year                 -38.28%      -17.96%
#
# Avg. Drawdown              -2.0%        -1.16%
# Avg. Drawdown Days         29           31
# Recovery Factor            3.08         3.67
# Ulcer Index                0.15         0.07
# Serenity Index             0.51         0.66
#
# Avg. Up Month              3.55%        1.9%
# Avg. Down Month            -4.52%       -2.18%
# Win Days %                 54.51%       54.5%
# Win Month %                63.88%       64.32%
# Win Quarter %              71.43%       64.94%
# Win Year %                 75.0%        85.0%
#
# Beta                       -            -0.03
# Alpha                      -            0.07
# Correlation                -            -7.79%
# Treynor Ratio              -            -6856.4%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2007-07-12  2009-03-06  2011-05-16  1405    -32.228629        -29.186640
# 2  2020-02-21  2020-03-20  2020-07-15   146    -16.059193        -14.811934
# 3  2005-03-07  2006-02-06  2006-12-01   635    -11.619607        -11.366292
# 4  2022-08-19  2023-03-22  2023-06-28   314     -7.210450         -7.008400
# 5  2011-05-19  2011-08-09  2011-10-11   146     -7.186632         -5.403120
# <h4>Strategy Visualization</h4>

# %% [markdown]
# # Minimizing Market Exposure

# %%
def mfl(data, stocks_to_use, col_name, exp, min_exp_weights, lambda_reg):
    def objective_cvxpy(weights, vol, betas, min_exp_weights, lambda_reg):
        # Initialize the alternative objective
        factor_exposure  = 0.0
        # Loop through each factor and calculate its contribution to the objective
        for factor, weight in min_exp_weights.items():
            port_beta = cp.matmul(weights, betas[factor])
            factor_exposure += weight * cp.square(port_beta)
            
        port_vol = cp.square(cp.matmul(weights, vol))
        l2_reg = cp.norm(weights, 2)**2
        return factor_exposure + port_vol + lambda_reg * l2_reg

    collect_weight = []
    count = 0 
    print(f'Processing {type}...')
    for date, row in stocks_to_use.iterrows():
        stocks = stocks_to_use.loc[stocks_to_use.index == date][col_name][0]
        # Get betas for given stocks at day t
        betas = exp.loc[exp.index.get_level_values('date') == date]
        betas = get_stocks_data(betas, stocks)
        betas = betas.fillna(0)
        # Get returns for given stocks at day t
        vol = data.loc[data.index.get_level_values('date') == date][['vol']]
        vol = get_stocks_data(vol, stocks)

        # CVXPY setup
        weights = cp.Variable(betas.shape[0])
        objective = cp.Minimize(objective_cvxpy(weights, vol, betas, min_exp_weights, lambda_reg))
        constraints = [
            cp.sum(weights) == 1,
            weights >= 0.001,
            weights <= 0.10
        ]
        prob = cp.Problem(objective, constraints)
        prob.solve(solver='ECOS')
        collect_weight.append(weights.value)
        
        # Track performance
        if count % 30 == 0:
            print(date)
        count += 1
    
    return collect_weight

# %%
def create_stock_list_df(data):
    permno_per_date = []
    date_unique = data.index.get_level_values('date').unique()
    for date_group in date_unique:
        stocks = data.loc[data.index.get_level_values('date') == date_group].index.get_level_values('permno')
        permno_per_date.append(stocks.values.tolist())
    
    stocks_to_use = pd.DataFrame(index=date_unique) 
    stocks_to_use['stock'] = permno_per_date
    return stocks_to_use

# %%
# Expected Return
long_short_stocks['RET_01_expected'] = long_short_stocks.groupby('permno')['RET_01'].shift(1)
long_short_stocks = set_timeframe(long_short_stocks, '2008-01-01', '2023-01-01')

# %%
long_short_permnos = create_stock_list_df(long_short_stocks)

# %%
long_short_permnos['long'] = long_short_permnos['stock'].apply(lambda x: x[:25])
long_short_permnos['short'] = long_short_permnos['stock'].apply(lambda x: x[25:])

# %%
sb_sector = PrepFactor(live=live, factor_name='factor_sb_sector', group='permno', interval='D', kind='price', stock=stock, div=False, start=start, end=current_date, save=False).prep()
# Out:
# Creating factor_sb_sector ---------------------------------- | ✔
# Shape: (3104852, 32)

# %%
factor_col = f'SPY_RET_01_spy_01_{window}'
exp = beta_spy[[factor_col]]
min_exp_weights = {
     f'SPY_RET_01_spy_01_{window}' : 1.0
}

factor_col = ['XLB_RET_01_sector_01_126', 'XLE_RET_01_sector_01_126', 'XLF_RET_01_sector_01_126', 'XLI_RET_01_sector_01_126',
              'XLK_RET_01_sector_01_126', 'XLP_RET_01_sector_01_126', 'XLU_RET_01_sector_01_126', 'XLV_RET_01_sector_01_126',
              'XLY_RET_01_sector_01_126']
exp = sb_sector[factor_col]
min_exp_weights = {
    'XLB_RET_01_sector_01_126': 1,
    'XLE_RET_01_sector_01_126': 1,
    'XLF_RET_01_sector_01_126': 1,
    'XLI_RET_01_sector_01_126': 1,
    'XLK_RET_01_sector_01_126': 1,
    'XLP_RET_01_sector_01_126': 1,
    'XLU_RET_01_sector_01_126': 1,
    'XLV_RET_01_sector_01_126': 1,
    'XLY_RET_01_sector_01_126': 1
}
lambda_reg = 1

# %%
test = set_timeframe(long_short_permnos, '2009-01-01', '2010-01-01')

# %%
long_min_weights = mfl(data=long_short_stocks, stocks_to_use=long_short_permnos, col_name='long', exp=exp, min_exp_weights=min_exp_weights, lambda_reg=lambda_reg)
# Out:
# Processing <class 'type'>...
# 2008-01-02 00:00:00
# 2008-02-14 00:00:00
# 2008-03-31 00:00:00
# 2008-05-12 00:00:00
# 2008-06-24 00:00:00
# 2008-08-06 00:00:00
# 2008-09-18 00:00:00
# 2008-10-30 00:00:00
# 2008-12-12 00:00:00
# 2009-01-28 00:00:00
# 2009-03-12 00:00:00
# 2009-04-24 00:00:00
# 2009-06-08 00:00:00
# 2009-07-21 00:00:00
# 2009-09-01 00:00:00
# 2009-10-14 00:00:00
# 2009-11-25 00:00:00
# 2010-01-11 00:00:00
# 2010-02-24 00:00:00
# 2010-04-08 00:00:00
# 2010-05-20 00:00:00
# 2010-07-02 00:00:00
# 2010-08-16 00:00:00
# 2010-09-28 00:00:00
# 2010-11-09 00:00:00
# 2010-12-22 00:00:00
# 2011-02-04 00:00:00
# 2011-03-21 00:00:00
# 2011-05-03 00:00:00
# 2011-06-15 00:00:00
# 2011-07-28 00:00:00
# 2011-09-09 00:00:00
# 2011-10-21 00:00:00
# 2011-12-05 00:00:00
# 2012-01-19 00:00:00
# 2012-03-02 00:00:00
# 2012-04-16 00:00:00
# 2012-05-29 00:00:00
# 2012-07-11 00:00:00
# 2012-08-22 00:00:00
# 2012-10-04 00:00:00
# 2012-11-19 00:00:00
# 2013-01-03 00:00:00
# 2013-02-15 00:00:00
# 2013-04-02 00:00:00
# 2013-05-14 00:00:00
# 2013-06-26 00:00:00
# 2013-08-08 00:00:00
# 2013-09-20 00:00:00
# 2013-11-01 00:00:00
# 2013-12-16 00:00:00
# 2014-01-30 00:00:00
# 2014-03-14 00:00:00
# 2014-04-28 00:00:00
# 2014-06-10 00:00:00
# 2014-07-23 00:00:00
# 2014-09-04 00:00:00
# 2014-10-16 00:00:00
# 2014-11-28 00:00:00
# 2015-01-13 00:00:00
# 2015-02-26 00:00:00
# 2015-04-10 00:00:00
# 2015-05-22 00:00:00
# 2015-07-07 00:00:00
# 2015-08-18 00:00:00
# 2015-09-30 00:00:00
# 2015-11-11 00:00:00
# 2015-12-24 00:00:00
# 2016-02-09 00:00:00
# 2016-03-23 00:00:00
# 2016-05-05 00:00:00
# 2016-06-17 00:00:00
# 2016-08-01 00:00:00
# 2016-09-13 00:00:00
# 2016-10-25 00:00:00
# 2016-12-07 00:00:00
# 2017-01-23 00:00:00
# 2017-03-07 00:00:00
# 2017-04-19 00:00:00
# 2017-06-01 00:00:00
# 2017-07-14 00:00:00
# 2017-08-25 00:00:00
# 2017-10-09 00:00:00
# 2017-11-20 00:00:00
# 2018-01-04 00:00:00
# 2018-02-16 00:00:00
# 2018-04-03 00:00:00
# 2018-05-15 00:00:00
# 2018-06-27 00:00:00
# 2018-08-09 00:00:00
# 2018-09-21 00:00:00
# 2018-11-02 00:00:00
# 2018-12-18 00:00:00
# 2019-02-01 00:00:00
# 2019-03-18 00:00:00
# 2019-04-30 00:00:00
# 2019-06-12 00:00:00
# 2019-07-25 00:00:00
# 2019-09-06 00:00:00
# 2019-10-18 00:00:00
# 2019-12-02 00:00:00
# 2020-01-15 00:00:00
# 2020-02-28 00:00:00
# 2020-04-13 00:00:00
# 2020-05-26 00:00:00
# 2020-07-08 00:00:00
# 2020-08-19 00:00:00
# 2020-10-01 00:00:00
# 2020-11-12 00:00:00
# 2020-12-28 00:00:00
# 2021-02-10 00:00:00
# 2021-03-25 00:00:00
# 2021-05-07 00:00:00
# 2021-06-21 00:00:00
# 2021-08-03 00:00:00
# 2021-09-15 00:00:00
# 2021-10-27 00:00:00
# 2021-12-09 00:00:00
# 2022-01-24 00:00:00
# 2022-03-08 00:00:00
# 2022-04-20 00:00:00
# 2022-06-02 00:00:00
# 2022-07-18 00:00:00
# 2022-08-29 00:00:00
# 2022-10-11 00:00:00
# 2022-11-22 00:00:00

# %%
short_min_weights = mfl(data=long_short_stocks, stocks_to_use=long_short_permnos, col_name='short', exp=exp, min_exp_weights=min_exp_weights, alpha=alpha, lambda_reg=lambda_reg)
# Out:
# Processing <class 'type'>...
# 2008-01-02 00:00:00
# 2008-02-14 00:00:00
# 2008-03-31 00:00:00
# 2008-05-12 00:00:00
# 2008-06-24 00:00:00
# 2008-08-06 00:00:00
# 2008-09-18 00:00:00
# 2008-10-30 00:00:00
# 2008-12-12 00:00:00
# 2009-01-28 00:00:00
# 2009-03-12 00:00:00
# 2009-04-24 00:00:00
# 2009-06-08 00:00:00
# 2009-07-21 00:00:00
# 2009-09-01 00:00:00
# 2009-10-14 00:00:00
# 2009-11-25 00:00:00
# 2010-01-11 00:00:00
# 2010-02-24 00:00:00
# 2010-04-08 00:00:00
# 2010-05-20 00:00:00
# 2010-07-02 00:00:00
# 2010-08-16 00:00:00
# 2010-09-28 00:00:00
# 2010-11-09 00:00:00
# 2010-12-22 00:00:00
# 2011-02-04 00:00:00
# 2011-03-21 00:00:00
# 2011-05-03 00:00:00
# 2011-06-15 00:00:00
# 2011-07-28 00:00:00
# 2011-09-09 00:00:00
# 2011-10-21 00:00:00
# 2011-12-05 00:00:00
# 2012-01-19 00:00:00
# 2012-03-02 00:00:00
# 2012-04-16 00:00:00
# 2012-05-29 00:00:00
# 2012-07-11 00:00:00
# 2012-08-22 00:00:00
# 2012-10-04 00:00:00
# 2012-11-19 00:00:00
# 2013-01-03 00:00:00
# 2013-02-15 00:00:00
# 2013-04-02 00:00:00
# 2013-05-14 00:00:00
# 2013-06-26 00:00:00
# 2013-08-08 00:00:00
# 2013-09-20 00:00:00
# 2013-11-01 00:00:00
# 2013-12-16 00:00:00
# 2014-01-30 00:00:00
# 2014-03-14 00:00:00
# 2014-04-28 00:00:00
# 2014-06-10 00:00:00
# 2014-07-23 00:00:00
# 2014-09-04 00:00:00
# 2014-10-16 00:00:00
# 2014-11-28 00:00:00
# 2015-01-13 00:00:00
# 2015-02-26 00:00:00
# 2015-04-10 00:00:00
# 2015-05-22 00:00:00
# 2015-07-07 00:00:00
# 2015-08-18 00:00:00
# 2015-09-30 00:00:00
# 2015-11-11 00:00:00
# 2015-12-24 00:00:00
# 2016-02-09 00:00:00
# 2016-03-23 00:00:00
# 2016-05-05 00:00:00
# 2016-06-17 00:00:00
# 2016-08-01 00:00:00
# 2016-09-13 00:00:00
# 2016-10-25 00:00:00
# 2016-12-07 00:00:00
# 2017-01-23 00:00:00
# 2017-03-07 00:00:00
# 2017-04-19 00:00:00
# 2017-06-01 00:00:00
# 2017-07-14 00:00:00
# 2017-08-25 00:00:00
# 2017-10-09 00:00:00
# 2017-11-20 00:00:00
# 2018-01-04 00:00:00
# 2018-02-16 00:00:00
# 2018-04-03 00:00:00
# 2018-05-15 00:00:00
# 2018-06-27 00:00:00
# 2018-08-09 00:00:00
# 2018-09-21 00:00:00
# 2018-11-02 00:00:00
# 2018-12-18 00:00:00
# 2019-02-01 00:00:00
# 2019-03-18 00:00:00
# 2019-04-30 00:00:00
# 2019-06-12 00:00:00
# 2019-07-25 00:00:00
# 2019-09-06 00:00:00
# 2019-10-18 00:00:00
# 2019-12-02 00:00:00
# 2020-01-15 00:00:00
# 2020-02-28 00:00:00
# 2020-04-13 00:00:00
# 2020-05-26 00:00:00
# 2020-07-08 00:00:00
# 2020-08-19 00:00:00
# 2020-10-01 00:00:00
# 2020-11-12 00:00:00
# 2020-12-28 00:00:00
# 2021-02-10 00:00:00
# 2021-03-25 00:00:00
# 2021-05-07 00:00:00
# 2021-06-21 00:00:00
# 2021-08-03 00:00:00
# 2021-09-15 00:00:00
# 2021-10-27 00:00:00
# 2021-12-09 00:00:00
# 2022-01-24 00:00:00
# 2022-03-08 00:00:00
# 2022-04-20 00:00:00
# 2022-06-02 00:00:00
# 2022-07-18 00:00:00
# 2022-08-29 00:00:00
# 2022-10-11 00:00:00
# 2022-11-22 00:00:00

# %%
long_stocks = long_short_stocks.groupby(level='date').head(25)
short_stocks = long_short_stocks.groupby(level='date').tail(-25)

# %%
def calc_min_ret(data, weight, type):
    flattened_array = np.concatenate(weight).flatten()
    flattened_weight = flattened_array.tolist()
    new_exposure = data.copy(deep=True)
    new_exposure['exp_weight'] = flattened_weight
    if type == 'long':
        new_exposure['total_ret'] = new_exposure['RET_01'] * new_exposure['exp_weight'] * 1
    elif type == 'short':
        new_exposure['total_ret'] = new_exposure['RET_01'] * new_exposure['exp_weight'] * -1
    total_ret = new_exposure.groupby('date').total_ret.sum()
    return new_exposure, total_ret

# %%
long_df, long_ret = calc_min_ret(long_stocks[['RET_01']], long_min_weights, 'long')

# %%
short_df, short_ret = calc_min_ret(short_stocks[['RET_01']], short_min_weights, 'short')

# %%
total_ret = 0.5 * long_ret + 0.5 * short_ret

# %%
inv_long = long_stocks.groupby('date').total_ret.sum()

# %%
qs.reports.full(long_ret, 'SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2008-01-03   2008-01-03
# End Period                 2022-12-30   2022-12-30
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          163.87%      287.86%
# CAGR﹪                     4.57%        6.44%
#
# Sharpe                     0.42         0.88
# Prob. Sharpe Ratio         94.58%       99.96%
# Smart Sharpe               0.39         0.84
# Sortino                    0.58         1.22
# Smart Sortino              0.55         1.16
# Sortino/√2                 0.41         0.86
# Smart Sortino/√2           0.39         0.82
# Omega                      1.18         1.18
#
# Max Drawdown               -52.98%      -34.4%
# Longest DD Days            1714         1190
# Volatility (ann.)          20.79%       10.95%
# R^2                        0.01         0.01
# Information Ratio          0.0          0.0
# Calmar                     0.09         0.19
# Skew                       -0.05        -0.71
# Kurtosis                   13.62        12.06
#
# Expected Daily %           0.03%        0.04%
# Expected Monthly %         0.54%        0.76%
# Expected Yearly %          6.68%        9.46%
# Kelly Criterion            -0.15%       -2.05%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -2.12%       -1.1%
# Expected Shortfall (cVaR)  -2.12%       -1.1%
#
# Max Consecutive Wins       14           14
# Max Consecutive Losses     8            8
# Gain/Pain Ratio            0.09         0.18
# Gain/Pain (1M)             0.49         0.92
#
# Payoff Ratio               0.84         0.78
# Profit Factor              1.09         1.18
# Common Sense Ratio         0.97         1.17
# CPC Index                  0.49         0.51
# Tail Ratio                 0.9          0.99
# Outlier Win Ratio          3.28         5.82
# Outlier Loss Ratio         3.52         6.62
#
# MTD                        -6.19%       -4.62%
# 3M                         5.41%        5.05%
# 6M                         0.55%        2.1%
# YTD                        -19.48%      1.77%
# 1Y                         -19.91%      1.76%
# 3Y (ann.)                  3.8%         4.57%
# 5Y (ann.)                  4.23%        7.01%
# 10Y (ann.)                 7.18%        8.26%
# All-time (ann.)            4.57%        6.44%
#
# Best Day                   14.52%       6.34%
# Worst Day                  -10.94%      -6.29%
# Best Month                 12.7%        13.52%
# Worst Month                -16.52%      -17.58%
# Best Year                  29.69%       30.61%
# Worst Year                 -37.74%      -20.84%
#
# Avg. Drawdown              -2.05%       -1.17%
# Avg. Drawdown Days         27           19
# Recovery Factor            2.44         4.2
# Ulcer Index                0.14         0.08
# Serenity Index             0.48         0.89
#
# Avg. Up Month              3.6%         2.59%
# Avg. Down Month            -5.2%        -3.07%
# Win Days %                 54.4%        55.19%
# Win Month %                63.89%       67.22%
# Win Quarter %              70.0%        75.0%
# Win Year %                 66.67%       93.33%
#
# Beta                       -            -0.04
# Alpha                      -            0.1
# Correlation                -            -7.91%
# Treynor Ratio              -            -6912.68%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2008-01-10  2009-03-06  2011-04-13  1190    -34.399529        -31.351339
# 2  2020-02-14  2020-03-20  2020-08-26   195    -25.478755        -21.296257
# 3  2011-07-07  2011-08-05  2011-11-04   121     -9.548066         -9.289652
# 4  2022-04-20  2022-06-15  2022-08-11   114     -8.664452         -8.520479
# 5  2022-08-19  2022-09-29  2022-11-21    95     -8.249483         -7.966720
# <h4>Strategy Visualization</h4>
